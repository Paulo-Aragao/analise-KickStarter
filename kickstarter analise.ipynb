# %% [markdown]
# # Limpandos os dados

# %%
import pandas as pd
import datetime

# %%
kick_starter = pd.read_csv("kickstarter.csv");

# %%
kick_starter.drop_duplicates(subset="blurb",keep = False, inplace = True)

# %%
kick_starter.columns
# Out:
# Index(['backers_count', 'blurb', 'category', 'converted_pledged_amount',
#        'country', 'created_at', 'creator', 'currency', 'currency_symbol',
#        'currency_trailing_code', 'current_currency', 'deadline',
#        'disable_communication', 'friends', 'fx_rate', 'goal', 'id',
#        'is_backing', 'is_starrable', 'is_starred', 'launched_at', 'location',
#        'name', 'permissions', 'photo', 'pledged', 'profile', 'slug',
#        'source_url', 'spotlight', 'staff_pick', 'state', 'state_changed_at',
#        'static_usd_rate', 'urls', 'usd_pledged', 'usd_type'],
#       dtype='object')

# %%
kick_starter.location.head(10)
# Out:
# 0     {"id":906057,"name":"Stockholm","slug":"stockh...
# 1     {"id":1100661,"name":"Brisbane","slug":"brisba...
# 2     {"id":2363919,"name":"Big Bear Lake","slug":"b...
# 6     {"id":2391585,"name":"Detroit","slug":"detroit...
# 7     {"id":2424766,"name":"Houston","slug":"houston...
# 9     {"id":2499775,"name":"Stevensville","slug":"st...
# 10    {"id":2442047,"name":"Los Angeles","slug":"los...
# 11    {"id":2450080,"name":"Miami Beach","slug":"mia...
# 12    {"id":2493227,"name":"Shreveport","slug":"shre...
# 13    {"id":2442047,"name":"Los Angeles","slug":"los...
# Name: location, dtype: object

# %%
kick_starter.loc[kick_starter["blurb"]=="blurb"]
# Out:
# Empty DataFrame
# Columns: [backers_count, blurb, category, converted_pledged_amount, country, created_at, creator, currency, currency_symbol, currency_trailing_code, current_currency, deadline, disable_communication, friends, fx_rate, goal, id, is_backing, is_starrable, is_starred, launched_at, location, name, permissions, photo, pledged, profile, slug, source_url, spotlight, staff_pick, state, state_changed_at, static_usd_rate, urls, usd_pledged, usd_type]
# Index: []
#
# [0 rows x 37 columns]

# %%
kick_starter.isnull().sum()
# Out:
# backers_count                    0
# blurb                            0
# category                         0
# converted_pledged_amount         0
# country                          0
# created_at                       0
# creator                          0
# currency                         0
# currency_symbol                  0
# currency_trailing_code           0
# current_currency                 0
# deadline                         0
# disable_communication            0
# friends                     153632
# fx_rate                          0
# goal                             0
# id                               0
# is_backing                  153632
# is_starrable                     0
# is_starred                  153632
# launched_at                      0
# location                       213
# name                             0
# permissions                 153632
# photo                            0
# pledged                          0
# profile                          0
# ...

# %%
kick_starter.drop(kick_starter.columns.difference(['backers_count','converted_pledged_amount','currency',"category","country","name","location","goal","state"]), axis=1, inplace=True)

# %%
kick_starter.head()
# Out:
#   backers_count                                           category  \
# 0             0  {"id":338,"name":"Robots","slug":"technology/r...
# 1             5  {"id":325,"name":"Calendars","slug":"publishin...
# 2             1  {"id":293,"name":"Drama","slug":"film & video/...
# 6             3  {"id":293,"name":"Drama","slug":"film & video/...
# 7             1  {"id":337,"name":"Gadgets","slug":"technology/...
#
#   converted_pledged_amount country currency      goal  \
# 0                        0      SE      SEK  39250000
# 1                      154      AU      AUD      1000
# 2                        1      US      USD      5000
# 6                       17      US      USD   1000000
# 7                        1      US      USD     10000
#
#                                             location  \
# 0  {"id":906057,"name":"Stockholm","slug":"stockh...
# 1  {"id":1100661,"name":"Brisbane","slug":"brisba...
# 2  {"id":2363919,"name":"Big Bear Lake","slug":"b...
# ...

# %%
kick_starter = kick_starter[kick_starter['location'].map(type) != float]

# %%
lista = []
for string in kick_starter.category:
    string = string.split(",")[1][7:]
    lista.append(string[1:-1])

# %%
city = []
for string in kick_starter.location:
    string = string.split(",")[1][7:]
    city.append(string[1:-1])

# %%
len(city)
# Out:
# 153423

# %%
kick_starter.category = pd.Series(lista)
kick_starter.location = pd.Series(city)

# %%
print(len(city))
print(len(lista))
# Out:
# 153423
# 153423

# %%
kick_starter.head()
# Out:
#   backers_count          category converted_pledged_amount country currency  \
# 0             0            Robots                        0      SE      SEK
# 1             5         Calendars                      154      AU      AUD
# 2             1             Drama                        1      US      USD
# 6             3          Painting                       17      US      USD
# 7             1  Camera Equipment                        1      US      USD
#
#        goal       location                                               name  \
# 0  39250000      Stockholm  OMNI - Intelligent Construction Robots (Canceled)
# 1      1000       Brisbane                    Diamond's 2015 Cosplay Calendar
# 2      5000  Big Bear Lake                                    The Lady In RED
# 6   1000000    Los Angeles   "SHADY BIZZNESS' The Eminem Movie Beyond 8 Mile"
# 7     10000    Miami Beach                              Doggy Urine Deflector
#
#       state
# 0  canceled
# 1    failed
# ...

# %%
kick_starter.head()
# Out:
#   backers_count          category converted_pledged_amount country currency  \
# 0             0            Robots                        0      SE      SEK
# 1             5         Calendars                      154      AU      AUD
# 2             1             Drama                        1      US      USD
# 6             3          Painting                       17      US      USD
# 7             1  Camera Equipment                        1      US      USD
#
#        goal       location                                               name  \
# 0  39250000      Stockholm  OMNI - Intelligent Construction Robots (Canceled)
# 1      1000       Brisbane                    Diamond's 2015 Cosplay Calendar
# 2      5000  Big Bear Lake                                    The Lady In RED
# 6   1000000    Los Angeles   "SHADY BIZZNESS' The Eminem Movie Beyond 8 Mile"
# 7     10000    Miami Beach                              Doggy Urine Deflector
#
#       state
# 0  canceled
# 1    failed
# ...

# %%
kick_starter.isnull().sum()
# Out:
# backers_count                   0
# category                    41442
# converted_pledged_amount        0
# country                         0
# currency                        0
# goal                            0
# location                    41442
# name                            0
# state                           0
# dtype: int64

# %%
kick_starter.drop(kick_starter[kick_starter.category.isnull()].index,inplace = True)
kick_starter.drop(kick_starter[kick_starter.location.isnull()].index,inplace = True)

# %%
kick_starter.isnull().sum()
# Out:
# backers_count               0
# category                    0
# converted_pledged_amount    0
# country                     0
# currency                    0
# goal                        0
# location                    0
# name                        0
# state                       0
# dtype: int64

# %%
kick_starter.head()
# Out:
#   backers_count          category converted_pledged_amount country currency  \
# 0             0            Robots                        0      SE      SEK
# 1             5         Calendars                      154      AU      AUD
# 2             1             Drama                        1      US      USD
# 6             3          Painting                       17      US      USD
# 7             1  Camera Equipment                        1      US      USD
#
#        goal       location                                               name  \
# 0  39250000      Stockholm  OMNI - Intelligent Construction Robots (Canceled)
# 1      1000       Brisbane                    Diamond's 2015 Cosplay Calendar
# 2      5000  Big Bear Lake                                    The Lady In RED
# 6   1000000    Los Angeles   "SHADY BIZZNESS' The Eminem Movie Beyond 8 Mile"
# 7     10000    Miami Beach                              Doggy Urine Deflector
#
#       state
# 0  canceled
# 1    failed
# ...

# %% [markdown]
# # Analisando a area de games do kickstarter

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
kick_starter.category = kick_starter.category.str.lower()

# %%
kick_starter.head()
# Out:
#   backers_count          category converted_pledged_amount country currency  \
# 0             0            robots                        0      SE      SEK
# 1             5         calendars                      154      AU      AUD
# 2             1             drama                        1      US      USD
# 6             3          painting                       17      US      USD
# 7             1  camera equipment                        1      US      USD
#
#        goal       location                                               name  \
# 0  39250000      Stockholm  OMNI - Intelligent Construction Robots (Canceled)
# 1      1000       Brisbane                    Diamond's 2015 Cosplay Calendar
# 2      5000  Big Bear Lake                                    The Lady In RED
# 6   1000000    Los Angeles   "SHADY BIZZNESS' The Eminem Movie Beyond 8 Mile"
# 7     10000    Miami Beach                              Doggy Urine Deflector
#
#       state
# 0  canceled
# 1    failed
# ...

# %%
top_30 = kick_starter.category.value_counts()[0:30]

# %%
top_30 = pd.DataFrame(top_30)
top_30 = top_30.sort_values(by=['category'],ascending=True)
top_30.head()
# Out:
#                 category
# shorts              1464
# fiction             1505
# video games         1508
# playing cards       1512
# graphic design      1517

# %%
colors = []
for x in range(0,30):
    colors.append((0.0,1-x/30,1.0))

# %%
y_pos = np.arange(len(top_30.category))

plt.figure(figsize=(10,14))
plt.barh(y_pos, top_30.category, color=colors)
plt.yticks(y_pos, top_30.index)
plt.xlabel('numero de projetos')
plt.title('Numero de de projetos por area de atuação')
plt.show()

# %% [markdown]
# Nesse estudo trabalheremos nas areas de tecnologia, com um foco em video games

# %%
kick_games=kick_starter

# %%
def in_string(x):
    return "game" in x

# %%
kick_games["is_game"] = kick_games.category.apply(in_string)

# %%
kick_games.drop(kick_games[kick_games['is_game'] == False].index, inplace=True)

# %%
kick_games.head()
# Out:
#    backers_count    category converted_pledged_amount country currency   goal  \
# 14           156  live games                    18264      US      USD  14000
# 46             6  live games                      130      US      USD  15000
# 50             4  live games                       76      US      USD   5000
# 54            50  live games                     1728      CA      CAD   1000
# 89             6  live games                      131      US      USD    500
#
#           location                                               name  \
# 14         Chicago                      Slide (IE) - Dublin to Dublin
# 46     Minneapolis  Forbidden Noodles - Amazing Asian noodles at a...
# 50  Salt Lake City                                    Comunale Coffee
# 54    Conshohocken                                  I Can Be Anything
# 89         Deltona                      STATIC SHOCK live action film
#
#          state  is_game
# 14  successful     True
# 46      failed     True
# ...

# %%
games_types = kick_games.category.value_counts()
games_types
# Out:
# mobile games      1733
# video games       1508
# live games         873
# tabletop games     540
# games               63
# Name: category, dtype: int64

# %%
import seaborn as sns
sns.set_palette('Set2')
# %matplotlib inline

# %%
labels = list(games_types.index)
sizes = [games_types[0],games_types[1],games_types[2],games_types[3],games_types[4]]


fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')
plt.show()

# %%
kick_games.backers_count=kick_games.backers_count.astype(int)

# %%
games_backers = kick_games.pivot_table(index="category",values='backers_count',aggfunc="sum")
games_backers
# Out:
#                 backers_count
# category
# games                    2872
# live games             125788
# mobile games           284667
# tabletop games          74468
# video games            195706

# %%
list_label = list(games_backers.index)
labels = [list_label[2],list_label[4],list_label[1],list_label[3],list_label[0],]
sizes = [games_backers.backers_count[2],games_backers.backers_count[4],games_backers.backers_count[1],games_backers.backers_count[3],games_backers.backers_count[0]]


fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')
plt.show()

# %%
games_backers = kick_games.pivot_table(index="category",values='backers_count',aggfunc=np.mean)
games_backers
# Out:
#                 backers_count
# category
# games               45.587302
# live games         144.087056
# mobile games       164.262550
# tabletop games     137.903704
# video games        129.778515

# %%
list_label = list(games_backers.index)
labels = [list_label[2],list_label[4],list_label[1],list_label[3],list_label[0],]
sizes = [games_backers.backers_count[2],games_backers.backers_count[4],games_backers.backers_count[1],games_backers.backers_count[3],games_backers.backers_count[0]]


fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')
plt.show()

# %%
games_backers = kick_games.pivot_table(index="state",columns="category",values='name',aggfunc="count")
games_backers
# Out:
# category    games  live games  mobile games  tabletop games  video games
# state
# canceled      1.0        45.0          96.0            36.0         80.0
# failed       41.0       409.0         771.0           252.0        699.0
# live          NaN         5.0           7.0             3.0         13.0
# successful   21.0       409.0         852.0           248.0        714.0
# suspended     NaN         5.0           7.0             1.0          2.0

# %%
games_backers["mobile games"]=games_backers["mobile games"]/games_backers["mobile games"].sum()*100
games_backers["games"]=games_backers["games"]/games_backers["games"].sum()*100
games_backers["live games"]=games_backers["live games"]/games_backers["live games"].sum()*100
games_backers["tabletop games"]=games_backers["tabletop games"]/games_backers["tabletop games"].sum()*100
games_backers["video games"]=games_backers["video games"]/games_backers["video games"].sum()*100

# %%
games_backers = games_backers.T

# %%
games_backers
# Out:
# state           canceled     failed      live  successful  suspended
# category
# games           1.587302  65.079365       NaN   33.333333        NaN
# live games      5.154639  46.849943  0.572738   46.849943   0.572738
# mobile games    5.539527  44.489325  0.403924   49.163301   0.403924
# tabletop games  6.666667  46.666667  0.555556   45.925926   0.185185
# video games     5.305040  46.352785  0.862069   47.347480   0.132626

# %%
games_backers = games_backers.fillna(0)

# %%
labels = list(games_backers.columns)
sizes = [games_backers.canceled[0],games_backers.failed	[0],games_backers.live[0],games_backers.successful[0],games_backers.suspended[0]]
sizes2 = [games_backers.canceled[1],games_backers.failed	[1],games_backers.live[1],games_backers.successful[1],games_backers.suspended[1]]
sizes3 = [games_backers.canceled[2],games_backers.failed	[2],games_backers.live[2],games_backers.successful[2],games_backers.suspended[2]]
sizes4 = [games_backers.canceled[3],games_backers.failed	[3],games_backers.live[3],games_backers.successful[3],games_backers.suspended[3]]
sizes5 = [games_backers.canceled[4],games_backers.failed	[4],games_backers.live[4],games_backers.successful[4],games_backers.suspended[4]]

fig1, ax1 = plt.subplots(figsize=(7,7))
fig2, ax2 = plt.subplots(figsize=(7,7))
fig3, ax3 = plt.subplots(figsize=(7,7))
fig4, ax4 = plt.subplots(figsize=(7,7))
fig5, ax5 = plt.subplots(figsize=(7,7))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')
ax2.pie(sizes2, labels=labels, autopct='%1.1f%%', shadow=True)
ax2.axis('equal')
ax3.pie(sizes3, labels=labels, autopct='%1.1f%%', shadow=True)
ax3.axis('equal')
ax4.pie(sizes4, labels=labels, autopct='%1.1f%%', shadow=True)
ax4.axis('equal')
ax5.pie(sizes5, labels=labels, autopct='%1.1f%%', shadow=True)
ax5.axis('equal')
plt.show()

# %% [markdown]
# # trabalhando com mapas

# %%
world_cities = pd.read_csv("worldcities.csv")
world_countrys = pd.read_csv("all.csv")

# %%
world_cities.head()
# Out:
#           city   city_ascii      lat      lng country iso2 iso3   admin_name  \
# 0    Malishevë    Malisheve  42.4822  20.7458  Kosovo   XK  XKS    Malishevë
# 1      Prizren      Prizren  42.2139  20.7397  Kosovo   XK  XKS      Prizren
# 2  Zubin Potok  Zubin Potok  42.9144  20.6897  Kosovo   XK  XKS  Zubin Potok
# 3     Kamenicë     Kamenice  42.5781  21.5803  Kosovo   XK  XKS     Kamenicë
# 4         Viti         Viti  42.3214  21.3583  Kosovo   XK  XKS         Viti
#
#   capital  population          id
# 0   admin         NaN  1901597212
# 1   admin         NaN  1901360309
# 2   admin         NaN  1901608808
# 3   admin         NaN  1901851592
# 4   admin         NaN  1901328795

# %%
world_countrys = world_countrys.rename(columns={'name': 'country'})
world_countrys.drop(world_countrys.columns.difference(["country","alpha-2","alpha-3"]), axis=1, inplace=True)
world_countrys.head()
# Out:
#           country alpha-2 alpha-3
# 0     Afghanistan      AF     AFG
# 1   Åland Islands      AX     ALA
# 2         Albania      AL     ALB
# 3         Algeria      DZ     DZA
# 4  American Samoa      AS     ASM

# %%
world_cities.isnull().sum()
# Out:
# city             0
# city_ascii       0
# lat              0
# lng              0
# country          0
# iso2            31
# iso3             0
# admin_name     209
# capital       7779
# population    1667
# id               0
# dtype: int64

# %%
world_cities.drop(world_cities.columns.difference(["city_ascii","city","lat","lng","country","iso3"]), axis=1, inplace=True)

# %%
world_cities.head()
# Out:
#           city   city_ascii      lat      lng country iso3
# 0    Malishevë    Malisheve  42.4822  20.7458  Kosovo  XKS
# 1      Prizren      Prizren  42.2139  20.7397  Kosovo  XKS
# 2  Zubin Potok  Zubin Potok  42.9144  20.6897  Kosovo  XKS
# 3     Kamenicë     Kamenice  42.5781  21.5803  Kosovo  XKS
# 4         Viti         Viti  42.3214  21.3583  Kosovo  XKS

# %%
new = pd.merge(left = world_cities,right = world_countrys,on="country",how= "outer")
new.dropna(axis='rows',inplace=True)
new.head()
# Out:
#         city city_ascii      lat      lng country iso3 alpha-2 alpha-3
# 39     Sanaa      Sanaa  15.3547  44.2066   Yemen  YEM      YE     YEM
# 40     Marib      Marib  15.4210  45.3340   Yemen  YEM      YE     YEM
# 41  Al Jabīn   Al Jabin  14.7040  43.5990   Yemen  YEM      YE     YEM
# 42    Hajjah     Hajjah  15.6917  43.6021   Yemen  YEM      YE     YEM
# 43       Ibb        Ibb  13.9759  44.1709   Yemen  YEM      YE     YEM

# %%
new.set_index("country",inplace=True)

# %%
world_cities.set_index("city_ascii",inplace=True)

# %%
world_cities.head()
# Out:
#                     city      lat      lng country iso3
# city_ascii
# Malisheve      Malishevë  42.4822  20.7458  Kosovo  XKS
# Prizren          Prizren  42.2139  20.7397  Kosovo  XKS
# Zubin Potok  Zubin Potok  42.9144  20.6897  Kosovo  XKS
# Kamenice        Kamenicë  42.5781  21.5803  Kosovo  XKS
# Viti                Viti  42.3214  21.3583  Kosovo  XKS

# %%
def get_lat_and_lng(city):
    try:
        return float(world_cities.loc[[city]]["lat"]),float(world_cities.loc[[city]]["lng"])
    except:
        pass

# %%
def alpha3(row):
    try:
        return list(world_cities.loc[[row["location"]]]["iso3"])[-1]
    except:
        return "NaN"

# %%
kick_games["alpha-3"] = ""

# %%
kick_games["alpha-3"] = kick_games.apply(alpha3,axis=1)

# %%
kick_games.head()
# Out:
#     backers_count    category converted_pledged_amount country currency  \
# 14            156  live games                    18264      US      USD
# 46              6  live games                      130      US      USD
# 50              4  live games                       76      US      USD
# 54             50  live games                     1728      CA      CAD
# 89              6  live games                      131      US      USD
#
#      goal        location                                               name  \
# 14  14000         Chicago                      Slide (IE) - Dublin to Dublin
# 46  15000     Minneapolis  Forbidden Noodles - Amazing Asian noodles at a...
# 50   5000  Salt Lake City                                    Comunale Coffee
# 54   1000    Conshohocken                                  I Can Be Anything
# 89    500         Deltona                      STATIC SHOCK live action film
#
#          state  is_game alpha-3
# 14  successful     True     USA
# ...

# %%
pivot_games = kick_games.pivot_table(index="alpha-3",values="backers_count",aggfunc="count")
pivot_games.loc["NaN"] = 0
pivot_games
# Out:
#          backers_count
# alpha-3
# ARE                  1
# ARG                  5
# AUS                 66
# AUT                  2
# BEL                 16
# BGR                  2
# BIH                  1
# BLR                  3
# BLZ                  1
# BRA                  8
# CAN                213
# CHE                 14
# CHN                  8
# CMR                  1
# CUW                  1
# CZE                  2
# DEU                 44
# DMA                  1
# DNK                  2
# DOM                  1
# ESP                 75
# FIN                  3
# FRA                 24
# GBR                114
# GHA                  1
# HKG                 14
# HRV                  2
# HUN                  1
# IDN                  9
# IND                  2
# ...                ...
# ITA                 20
# JPN                 41
# KEN                  2
# KOR                  3
# LBN                  2
# LTU                  5
# LVA                  1
# ...

# %%
pivot_games.index
# Out:
# Index(['ARE', 'ARG', 'AUS', 'AUT', 'BEL', 'BGR', 'BIH', 'BLR', 'BLZ', 'BRA',
#        'CAN', 'CHE', 'CHN', 'CMR', 'CUW', 'CZE', 'DEU', 'DMA', 'DNK', 'DOM',
#        'ESP', 'FIN', 'FRA', 'GBR', 'GHA', 'HKG', 'HRV', 'HUN', 'IDN', 'IND',
#        'IRL', 'ISL', 'ISR', 'ITA', 'JPN', 'KEN', 'KOR', 'LBN', 'LTU', 'LVA',
#        'MEX', 'MYS', 'NAM', 'NLD', 'NOR', 'NZL', 'NaN', 'PHL', 'POL', 'ROU',
#        'RUS', 'SGP', 'SUR', 'SVN', 'SWE', 'THA', 'TUR', 'TZA', 'UKR', 'URY',
#        'USA', 'VNM', 'ZAF'],
#       dtype='object', name='alpha-3')

# %%
# !pip install folium

# %%
import folium
import json

# %%
geo_json_data = json.load(open("world-countries.json"))

# %%
geo_json_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Afghanistan'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[61.210817, 35.650072],
#       [62.230651, 35.270664],
#       [62.984662, 35.404041],
#       [63.193538, 35.857166],
#       [63.982896, 36.007957],
#       [64.546479, 36.312073],
#       [64.746105, 37.111818],
#       [65.588948, 37.305217],
#       [65.745631, 37.661164],
#       [66.217385, 37.39379],
#       [66.518607, 37.362784],
#       [67.075782, 37.356144],
#       [67.83, 37.144994],
#       [68.135562, 37.023115],
#       [68.859446, 37.344336],
#       [69.196273, 37.151144],
#       [69.518785, 37.608997],
#       [70.116578, 37.588223],
#       [70.270574, 37.735165],
#       [70.376304, 38.138396],
#       [70.806821, 38.486282],
#       [71.348131, 38.258905],
#       [71.239404, 37.953265],
#       [71.541918, 37.905774],
#       [71.448693, 37.065645],
#       [71.844638, 36.738171],
# ...

# %%
def get_country_name(alpha):
    if alpha in list(pivot_games.index):
        return alpha
    else:
        return "NaN"

# %%
for alpha in geo_json_data['features']: 
  alpha_ = alpha['id']
  alpha['properties']['backers_count'] = str(pivot_games.loc[get_country_name(alpha_), "backers_count"])

# %%
pivot_games["alpha-3"] = pivot_games.index
pivot_games.head()
# Out:
#          backers_count alpha-3
# alpha-3
# ARE                  1     ARE
# ARG                  5     ARG
# AUS                 66     AUS
# AUT                  2     AUT
# BEL                 16     BEL

# %%
m = folium.Map(
    location=[0,0],zoom_start=2,
    tiles='Stamen Terrain'
)

bins = np.linspace(pivot_games['backers_count'].min(),
                   pivot_games['backers_count'].max(),
                   10).tolist()


folium.Choropleth(
    geo_data=geo_json_data,
    data=pivot_games,
    name= "ID",
    columns=['alpha-3', 'backers_count'],
    key_on='feature.id',
    fill_color='Greens',
    fill_opacity=0.7,
    line_opacity=0.5,
    legend_name='#Numero de projetos nos países que possuem projetos da area de jogos',
    bins=bins
).add_to(m)

folium.LayerControl().add_to(k)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save(outfile="map.html")

# %%
kick_games.head()
# Out:
#     backers_count    category converted_pledged_amount country currency  \
# 14            156  live games                    18264      US      USD
# 46              6  live games                      130      US      USD
# 50              4  live games                       76      US      USD
# 54             50  live games                     1728      CA      CAD
# 89              6  live games                      131      US      USD
#
#      goal        location                                               name  \
# 14  14000         Chicago                      Slide (IE) - Dublin to Dublin
# 46  15000     Minneapolis  Forbidden Noodles - Amazing Asian noodles at a...
# 50   5000  Salt Lake City                                    Comunale Coffee
# 54   1000    Conshohocken                                  I Can Be Anything
# 89    500         Deltona                      STATIC SHOCK live action film
#
#          state  is_game alpha-3
# 14  successful     True     USA
# ...

# %%
kick_games.sort_values(by=['backers_count'],ascending=False,inplace=True)

# %%
kick_games.head(50)
# Out:
#         backers_count        category converted_pledged_amount country  \
# 40138           91585    mobile games                  5702153      US
# 90204           33741     video games                  1519680      US
# 27446           31774      live games                  1229015      US
# 58798           17218    mobile games                   470310      US
# 57148           14904  tabletop games                   545531      US
# 130460          14884  tabletop games                  1440345      US
# 142805           9044     video games                   384410      US
# 141927           6512      live games                   958792      US
# 102789           5910     video games                   203300      US
# 10484            4387     video games                   160904      US
# 102336           4256     video games                   121227      US
# 89495            4062    mobile games                   659301      US
# ...

# %%
from folium.features import CustomIcon

# %%
import itertools
def set_icons(serie,name):
    for x,y in zip(serie,name):
        try:
            lat,log = get_lat_and_lng(str(x))
            icon = folium.Icon(color='orange',
                              icon_color='blue',
                              icon='gamepad',
                              prefix='fa')
            folium.Marker ([lat, log],
                popup = '<i> '+str(y)+' </ i>',
                tooltip = str(x),
                icon=icon).add_to(m)
        except:
            pass
set_icons(kick_games["location"][0:150],kick_games["name"][0:150])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save(outfile="map2.html")

# %%
BRA_projects = kick_games.loc[kick_games["alpha-3"] == 'BRA']

# %%
m = folium.Map(
    location=[-22.9,-43.19],zoom_start=4,
    tiles='Stamen Terrain'
)
def set_icons(serie,name):
    for x,y in zip(serie,name):
        try:
            lat,log = get_lat_and_lng(str(x))
            icon = folium.Icon(color='orange',
                              icon_color='blue',
                              icon='gamepad',
                              prefix='fa')
            folium.Marker ([lat, log],
                popup = '<i> '+str(y)+' </ i>',
                tooltip = str(x),
                icon=icon).add_to(m)
        except:
            pass
set_icons(BRA_projects["location"],BRA_projects["name"])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save(outfile="map3.html")
